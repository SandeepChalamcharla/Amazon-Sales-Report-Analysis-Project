# %%
# Let's Work with Amazon Sales Report Project

# %%
# Let's Load and Inspect the Dataset

# %%
import pandas as pd
data = pd.read_csv('Amazon Sale Report.csv', encoding='ISO-8859-1', index_col='index')
data
# Out:
#                    Order ID      Date                        Status  \
# index
# 0       405-8078784-5731545  04-30-22                     Cancelled
# 1       171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  04-30-22                       Shipped
# 3       403-9615377-8133951  04-30-22                     Cancelled
# 4       407-1069790-7240320  04-30-22                       Shipped
# ...                     ...       ...                           ...
# 128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  408-7436540-8728312  05-31-22                       Shipped
#
#        Fulfilment Sales Channel ship-service-level  Category Size  \
# index
# 0        Merchant     Amazon.in           Standard   T-shirt    S
# ...

# %%
# Getting First 10 rows

# %%
data.head(10)
# Out:
#                   Order ID      Date                        Status Fulfilment  \
# index
# 0      405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1      171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2      404-0687676-7273146  04-30-22                       Shipped     Amazon
# 3      403-9615377-8133951  04-30-22                     Cancelled   Merchant
# 4      407-1069790-7240320  04-30-22                       Shipped     Amazon
# 5      404-1490984-4578765  04-30-22                       Shipped     Amazon
# 6      408-5748499-6859555  04-30-22                       Shipped     Amazon
# 7      406-7807733-3785945  04-30-22  Shipped - Delivered to Buyer   Merchant
# 8      407-5443024-5233168  04-30-22                     Cancelled     Amazon
# 9      402-4393761-0311520  04-30-22                       Shipped     Amazon
#
#       Sales Channel ship-service-level  Category Size Courier Status  Qty  \
# index
# ...

# %%
# Understanding the Data Types

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 128976 entries, 0 to 128974
# Data columns (total 20 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order ID            128976 non-null  object
#  1   Date                128976 non-null  object
#  2   Status              128976 non-null  object
#  3   Fulfilment          128976 non-null  object
#  4   Sales Channel       128976 non-null  object
#  5   ship-service-level  128976 non-null  object
#  6   Category            128976 non-null  object
#  7   Size                128976 non-null  object
#  8   Courier Status      128976 non-null  object
#  9   Qty                 128976 non-null  int64
#  10  currency            121176 non-null  object
#  11  Amount              121176 non-null  float64
#  12  ship-city           128941 non-null  object
#  13  ship-state          128941 non-null  object
#  14  ship-postal-code    128941 non-null  float64
# ...

# %%
# Getting basic stastics of the data

# %%
data.describe()
# Out:
#                  Qty         Amount  ship-postal-code  New  PendingS
# count  128976.000000  121176.000000     128941.000000  0.0       0.0
# mean        0.904401     648.562176     463945.677744  NaN       NaN
# std         0.313368     281.185041     191458.488954  NaN       NaN
# min         0.000000       0.000000     110001.000000  NaN       NaN
# 25%         1.000000     449.000000     382421.000000  NaN       NaN
# 50%         1.000000     605.000000     500033.000000  NaN       NaN
# 75%         1.000000     788.000000     600024.000000  NaN       NaN
# max        15.000000    5584.000000     989898.000000  NaN       NaN

# %%
# -- Data Cleaning--

# %%
# Removing Duplicates

# %%
data.drop_duplicates()
# Out:
#                    Order ID      Date                        Status  \
# index
# 0       405-8078784-5731545  04-30-22                     Cancelled
# 1       171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  04-30-22                       Shipped
# 3       403-9615377-8133951  04-30-22                     Cancelled
# 4       407-1069790-7240320  04-30-22                       Shipped
# ...                     ...       ...                           ...
# 128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  408-7436540-8728312  05-31-22                       Shipped
#
#        Fulfilment Sales Channel ship-service-level  Category Size  \
# index
# 0        Merchant     Amazon.in           Standard   T-shirt    S
# ...

# %%
# Let's Handle th Missing Values

# %%
data = data.drop(columns=['New', 'PendingS'], errors='ignore')

# Filling the missing values of columns
data['currency'].fillna("Unknown", inplace=True)
data['Amount'].fillna(data['Amount'].median(), inplace=True)
data['ship-city'].fillna(method='ffill', inplace=True)
data['ship-state'].fillna(method='ffill', inplace=True)
data['ship-postal-code'].fillna(method='ffill', inplace=True)
data['ship-country'].fillna(method='ffill', inplace=True)
data['fulfilled-by'].fillna("Unknown", inplace=True)

# Saving the cleaned data to a new CSV file
data.to_csv('Amazon_Sale_Report_Cleaned.csv', index=False)
data
# Out:
#                    Order ID      Date                        Status  \
# index
# 0       405-8078784-5731545  04-30-22                     Cancelled
# 1       171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  04-30-22                       Shipped
# 3       403-9615377-8133951  04-30-22                     Cancelled
# 4       407-1069790-7240320  04-30-22                       Shipped
# ...                     ...       ...                           ...
# 128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  408-7436540-8728312  05-31-22                       Shipped
#
#        Fulfilment Sales Channel ship-service-level  Category Size  \
# index
# 0        Merchant     Amazon.in           Standard   T-shirt    S
# ...

# %%
#---Sales Overview Analysis----

#Let's Perform 'Sales Overview Analysis' by Understanding overall sales performance, trends, and patterns over time

# %%
#Total Sales
total_sales = data['Amount'].sum()
total_sales
# Out:
# 83309170.25

# %%
#Total Units Sold
total_units_sold = data['Qty'].sum()
total_units_sold
# Out:
# 116646

# %%
# Tracking average sales per order
avg_sales_per_order = total_sales / data['Order ID'].nunique()
avg_sales_per_order
# Out:
# 692.9207616298896

# %%
# Total Orders
total_orders = data['Order ID'].nunique()
total_orders
# Out:
# 120229

# %%
# Identifying Sales Trends
## Time Series Analysis
data['Date'] = pd.to_datetime(data['Date'],format='%d-%m-%Y', errors='coerce')
monthly_sales = data.resample('M', on = 'Date')['Amount'].sum()
monthly_sales
# Out:
# Date
# 2022-01-31    3066601.33
# 2022-02-28    3180541.41
# 2022-03-31    3147536.16
# 2022-04-30    3171449.44
# 2022-05-31    3004346.25
# 2022-06-30    2892756.52
# 2022-07-31    2946870.37
# 2022-08-31    3062922.76
# 2022-09-30    2895270.46
# 2022-10-31    2741032.85
# 2022-11-30    2700161.13
# 2022-12-31    2693186.78
# Name: Amount, dtype: float64

# %%
#Sales by Channel
sales_by_channel = data.groupby('Sales Channel')['Amount'].sum()
sales_by_channel
# Out:
# Sales Channel
# Amazon.in     83234150.25
# Non-Amazon       75020.00
# Name: Amount, dtype: float64

# %%
#---Product Analysis----

# Let's do 'Product Analysis' by Identifying popular product categories, sizes, and quantities sold
# Identifying top categories by revenue and quantity.

category_sales = data.groupby('Category').agg({'Amount': 'sum', 'Qty': 'sum'})
category_sales
# Out:
#                Amount    Qty
# Category
# Blazzer   11697289.12  13943
# Perfume     829349.66   1051
# Shirt     23211990.08  45044
# Shoes       130197.76    153
# Socks       162857.50    399
# T-shirt   41168771.65  45292
# Trousers   5622166.30   9898
# Wallet      485633.18    863
# Watch          915.00      3

# %%
# Product Size and Quantity Analysis
# Finding top products by sales volume or quantity to identify bestsellers.

size_sales = data.groupby('Size')['Qty'].sum().sort_values(ascending=False)
size_sales
# Out:
# Size
# M       20138
# L       19706
# XL      18636
# XXL     16246
# S       15041
# 3XL     13360
# XS       9850
# Free     2070
# 6XL       688
# 5XL       513
# 4XL       398
# Name: Qty, dtype: int64

# %%
# ---Fulfillment Analysis---

# Analyzing Sales by Fulfillment Method

fulfillment_sales = data.groupby('fulfilled-by')['Amount'].sum()
fulfillment_sales
# Out:
# fulfilled-by
# Easy Ship    25312910.25
# Unknown      57996260.00
# Name: Amount, dtype: float64

# %%
#---Customer Segmentation---

# Analyzing Purchase Frequency 

order_frequency = data['Order ID'].value_counts()
order_frequency
# Out:
# Order ID
# 403-4984515-8861958    12
# 171-5057375-2831560    12
# 404-9932919-6662730    11
# 403-0173977-3041148    11
# 408-3317403-1729937    10
#                        ..
# 171-9107779-6893116     1
# 408-9376298-8017114     1
# 407-3992093-3258734     1
# 408-7043395-8664315     1
# 408-7436540-8728312     1
# Name: count, Length: 120229, dtype: int64

# %%
# Segmenting by Product Categories

category_segments = data.groupby('Category')['Order ID'].nunique()
category_segments
# Out:
# Category
# Blazzer     14984
# Perfume      1146
# Shirt       46499
# Shoes         144
# Socks         409
# T-shirt     47782
# Trousers    10141
# Wallet        897
# Watch           2
# Name: Order ID, dtype: int64

# %%
#---Geographical Analysis---

# Analyzing Sales by region

sales_by_city = data.groupby('ship-city')['Amount'].sum()
sales_by_city
# Out:
# ship-city
# (Chikmagalur disterict).     (N.R pur thaluku)     389.0
# (Via Cuncolim)Quepem,South Goa                    1163.0
# ,HYDERABAD                                         563.0
# ,raibarely road faizabad (Ayodhya)                1122.0
# ..katra                                            641.0
#                                                    ...
# yavatmal                                           735.0
# yazali                                             487.0
# yellapur                                           824.0
# zirakpur                                           852.0
# ýýýýýýýýýýýý                                      2003.0
# Name: Amount, Length: 8948, dtype: float64

# %%
sales_by_state = data.groupby('ship-state')['Amount'].sum()
sales_by_state
# Out:
# ship-state
# ANDAMAN & NICOBAR     165894.62
# ANDHRA PRADESH       3444734.86
# APO                      605.00
# AR                       493.00
# ARUNACHAL PRADESH      99470.00
#                         ...
# goa                     2467.00
# orissa                   597.00
# punjab                  9227.00
# rajasthan               3946.00
# rajsthan                 521.00
# Name: Amount, Length: 69, dtype: float64

# %%
# Finding High-Performing and Underperforming States

sales_by_state = data.groupby('ship-state')['Amount'].sum().reset_index()
sales_by_state
# Out:
#            ship-state      Amount
# 0   ANDAMAN & NICOBAR   165894.62
# 1      ANDHRA PRADESH  3444734.86
# 2                 APO      605.00
# 3                  AR      493.00
# 4   ARUNACHAL PRADESH    99470.00
# ..                ...         ...
# 64                goa     2467.00
# 65             orissa      597.00
# 66             punjab     9227.00
# 67          rajasthan     3946.00
# 68           rajsthan      521.00
#
# [69 rows x 2 columns]

# %%
# Top 5 High-Performing States

sales_by_state = sales_by_state.sort_values(by='Amount', ascending=False)
sales_by_state.head(5)
# Out:
#        ship-state       Amount
# 28    MAHARASHTRA  14062423.05
# 23      KARNATAKA  11047304.22
# 57      TELANGANA   7337030.08
# 59  UTTAR PRADESH   7244106.08
# 56     TAMIL NADU   6932869.30

# %%
# Bottom 5 Underperforming States

sales_by_state.tail(5)
# Out:
#      ship-state  Amount
# 45  Pondicherry   529.0
# 68     rajsthan   521.0
# 3            AR   493.0
# 53     Rajsthan   443.0
# 42           PB   399.0

# %%
# Let's do Visualizations

# %%
# Line Plots for Sales Trends Over Time (Monthly and Weekly)

import matplotlib.pyplot as plt
import seaborn as sns

# Monthly Sales Trend

monthly_sales = data.resample('M', on='Date')['Amount'].sum()
plt.figure(figsize=(12, 6))
plt.plot(monthly_sales.index, monthly_sales.values, marker='o', color='b', label="Monthly Sales")
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales Amount")
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
# Weekly Sales Trend

weekly_sales = data.resample('W', on='Date')['Amount'].sum()
plt.figure(figsize=(12, 6))
plt.plot(weekly_sales.index, weekly_sales.values, marker='o', color='g', label="Weekly Sales")
plt.title("Weekly Sales Trend")
plt.xlabel("Week")
plt.ylabel("Sales Amount")
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
# Let's Visualize 'Bar Charts' for Top Product Categories, Sizes, and Regions by Sales

# %%
# Bar chart for Top Product Categories by Sales

category_sales = data.groupby('Category')['Amount'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 4))
sns.barplot(x=category_sales.values, y=category_sales.index, palette='viridis')
plt.title("Top Product Categories by Sales")
plt.xlabel("Sales Amount")
plt.ylabel("Product Category")
plt.show()

# %%
# Bar chart for Top Sizes by Quantity Sold

size_sales = data.groupby('Size')['Qty'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=size_sales.values, y=size_sales.index, palette='rocket')
plt.title("Top Product Sizes by Quantity Sold")
plt.xlabel("Quantity Sold")
plt.ylabel("Size")
plt.show()

# %%
# Bar chart for Top States by Sales

top_states_sales = data.groupby('ship-state')['Amount'].sum().sort_values(ascending=False).head()
plt.figure(figsize=(10, 3))
sns.barplot(x=top_states_sales.values, y=top_states_sales.index, palette='coolwarm')
plt.title("Top States by Sales")
plt.xlabel("Sales Amount")
plt.ylabel("State")
plt.show()

# %%
# Bar chart for Bottom States by Sales
bottom_states_sales = data.groupby('ship-state')['Amount'].sum().sort_values(ascending=False).tail()
plt.figure(figsize=(10, 3))
sns.barplot(x=bottom_states_sales.values, y=bottom_states_sales.index, palette='coolwarm')
plt.title("Bottom States by Sales")
plt.xlabel("Sales Amount")
plt.ylabel("State")
plt.show()

# %%
# Let's Visualize Pie Charts for Sales Distribution by Channel and Fulfillment Method

# %%
# Pie Chart for Sales Distribution by Sales Channel

sales_by_channel = data.groupby('Sales Channel')['Amount'].sum()
plt.figure(figsize=(5, 5))
plt.pie(sales_by_channel, labels=sales_by_channel.index, autopct='%1.1f%%', startangle=140, colors=['#66b3ff','#99ff99'])
plt.title("Sales Distribution by Sales Channel")
plt.show()

# %%
# Pie Chart for Sales Distribution by Fulfillment Method

fulfillment_sales = data.groupby('fulfilled-by')['Amount'].sum()
plt.figure(figsize=(5, 5))
plt.pie(fulfillment_sales, labels=fulfillment_sales.index, autopct='%1.1f%%', startangle=140, colors=['#ff9999','#66b3ff'])
plt.title("Sales Distribution by Fulfillment Method")
plt.show()

# %%
# Let's Visualize bar plot as a Heatmap for Geographical Sales Distribution (States)

# %%
# State-level Sales Data for bar plot as a Heatmap

state_sales = data.groupby('ship-state')['Amount'].sum().reset_index()
state_sales
# Out:
#            ship-state      Amount
# 0   ANDAMAN & NICOBAR   165894.62
# 1      ANDHRA PRADESH  3444734.86
# 2                 APO      605.00
# 3                  AR      493.00
# 4   ARUNACHAL PRADESH    99470.00
# ..                ...         ...
# 64                goa     2467.00
# 65             orissa      597.00
# 66             punjab     9227.00
# 67          rajasthan     3946.00
# 68           rajsthan      521.00
#
# [69 rows x 2 columns]

# %%
# Using bar plot as a Heatmap

plt.figure(figsize=(15, 15))
sns.barplot(data=state_sales.sort_values(by="Amount", ascending=False), 
            x="Amount", y="ship-state", palette="YlGnBu")
plt.title("Geographical Sales Distribution by State")
plt.xlabel("Sales Amount")
plt.ylabel("State")
plt.show()

# %%
# Please identify the visuals above, along with the corresponding Business Insights and Recommendations.

# %%
#---Business Insights and Recommendations---#

# %%
# Executive Summary

# The Amazon Sales Report analysis aimed to provide insights into sales performance, product preferences, fulfillment methods, and customer segmentation. After examining the dataset, we have identified several key trends.

# **Total Sales:** The total sales amounted to ₹83,309,170.25, with a total of 116,646 units sold.
# **Sales Trends:** Sales showed steady growth in the first half of the year, peaking in April and May. However, a slight dip was observed in June.
# **Top-Selling Products:** T-shirts and Shirts were the highest-selling categories, with T-shirts contributing to over 40% of total sales.
# **Geographical Insights:** Maharashtra and Karnataka emerged as the highest-performing regions, while states like Pondicherry and Rajasthan underperformed.
# **Fulfillment Efficiency:** Easy Ship fulfilled 30% of total sales, with a larger share of the sales remaining under "Unknown."

# %%
# Detailed Analysis

#This section provides a deeper dive into each of the analysis objectives and area of improvements in each analysis.

# %%
# 1) Sales Overview Analysis

# **Total Sales and Units Sold**: With total sales amounting to 83,309,170.25 across 116,646 units, there is strong sales performance, particularly in popular months such as April, May, and June. Average sales per order stand at 692.92.
# **Sales Channel Insights**: The vast majority of sales (99.9%) are from Amazon.in, while the Non-Amazon channel represents only a marginal portion of the total revenue.
# **Recommendation**: Capitalize on Amazon.in as a primary sales platform but explore ways to boost the Non-Amazon channel, perhaps through exclusive product offerings or targeted promotions for broader market reach.

# %%
# 2) Product Analysis

# **Top Product Categories**: T-shirts and Shirts are the best-selling categories by both revenue and quantity, with significant sales in Blazers and Trousers as well.
# **Size Preferences**: Sizes "M," "L," and "XL" are the most popular, suggesting a customer preference for these sizes.
# **Underperforming Products**: Categories like Watches and Socks show lower sales, indicating lower demand or potential issues with visibility or product fit for the target market.
# **Recommendation**: Increase inventory for T-shirts, Shirts, and other high-demand categories, especially in sizes M, L, and XL. For low-demand items, consider bundling with popular products or discounting to improve clearance rates. Continuously monitor the performance of underperforming products to determine whether they should remain in the product lineup.

# %%
# 3) Fullfillment Analysis 

# **Fulfillment by Method**: Sales are split between "Easy Ship" (25.3 million) and "Unknown" (57.9 million). Orders fulfilled by "Easy Ship" tend to have fewer delays, likely contributing to better customer satisfaction.
# **Recommendation**: Shift more orders to reliable fulfillment methods like "Easy Ship" to improve delivery reliability and enhance customer experience. Review and clarify the "Unknown" fulfillment category to better assess its impact on customer satisfaction and delivery times.

# %%
# 4) Customer Segmentation

# **Order Frequency**: The average purchase frequency is 1.07 per customer, with a few customers showing repeated orders. Categories like Shirts and T-shirts have higher repeat order counts, indicating high customer loyalty and demand.
# **Category Segmentation**: Shirts and T-shirts have the highest unique order IDs, showing that they attract a larger portion of the customer base.
# **Recommendation**: Develop loyalty incentives or exclusive discounts for customers in high-demand product segments (e.g., Shirts and T-shirts) to encourage repeat purchases. Additionally, provide personalized recommendations based on previous orders to improve engagement.

# %%
# 5) Geographical Analysis

# **High-Performing Regions**: Maharashtra, Karnataka, Telangana, Uttar Pradesh, and Tamil Nadu are the top-performing states by sales volume, indicating high demand in these areas.
# **Underperforming Regions**: States like Pondicherry, Rajasthan (misspelled as "rajsthan" in the dataset), and Arunachal Pradesh show the lowest sales volumes.
# **Recommendation**: Focus on expanding market share in high-performing states through localized campaigns and enhanced inventory planning. For underperforming states, consider targeted ads to raise brand awareness or location-specific discounts to boost interest.

# %%
##---Key Business Insights--##

# **Inventory Optimization**: Maintain sufficient stock levels for popular products and sizes, especially before high-sales periods, to reduce stockouts and improve customer satisfaction.
# **Customer Retention and Loyalty**: Leveraging customer segmentation insights to design loyalty programs and personalized offers can increase purchase frequency and retention.
# **Regional Strategy**: Prioritize high-demand states for marketing and inventory allocation while using targeted marketing in underperforming regions to boost visibility.
# **Product Popularity:** T-shirts and Shirts dominate the sales in terms of both quantity and revenue. These products should be prioritized in marketing campaigns and inventory management.
# **Fulfillment Methods:** The "Easy Ship" method is the most used, but there is room for improvement in fulfillment, especially in regions with low performance.

# %%
##---Overall Business Recommendations---##

# **Expand Inventory for High-Demand Products**: Increase stock for best-selling items, especially T-shirts and Shirts, in the most popular sizes (M, L, and XL).
# **Optimize Fulfillment**: Improve consistency in the fulfillment process by minimizing delays in the "Unknown" category, and rely more on trusted methods like "Easy Ship."
# **Enhance Regional Marketing**: Concentrate resources on high-performing regions with regional promotions, while targeting underperforming states with localized ads or special incentives.
# **Increase Sales Channel Presence**: Focus on Amazon.in as a primary channel, but consider enhancing the Non-Amazon channel with exclusive offers to attract a broader audience.
# **Target Marketing Efforts:** Focus more on Maharashtra and Karnataka to capitalize on high-performing regions. For underperforming states, consider localized promotional offers.
